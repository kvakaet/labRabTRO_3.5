# %%
import matplotlib.pyplot as plt
import requests
from io import BytesIO
from PIL import Image
# %matplotlib inline

response = requests.get('https://sun9-27.userapi.com/impg/62RmH7jcWuVS-1OAQq37nDW0vKCLltsSyV0AIQ/tA3maB92u-M.jpg?size=480x590&quality=96&sign=b42d53186a64d8adf23f0c5ff1cc572d&type=album')
img = Image.open(BytesIO(response.content))
plt.imshow(img)
